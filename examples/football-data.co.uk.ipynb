# %%
import sys
sys.path.append("../")

import penaltyblog as pb

# %% [markdown]
# ### List the available countries to download data for

# %%
pb.footballdata.list_countries()
# Out:
# ['belgium',
#  'england',
#  'france',
#  'germany',
#  'greece',
#  'italy',
#  'portugal',
#  'scotland',
#  'spain',
#  'turkey']

# %% [markdown]
# ### Download the data for the English Premier League

# %%
pb.footballdata.fetch_data("England", 2020, 0)
# Out:
#     Div       Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0 2020-09-12  12:30            Fulham         Arsenal     0     3   A
# 1    E0 2020-09-12  15:00    Crystal Palace     Southampton     1     0   H
# 2    E0 2020-09-12  17:30         Liverpool           Leeds     4     3   H
# 3    E0 2020-09-12  20:00          West Ham       Newcastle     0     2   A
# 4    E0 2020-09-13  14:00         West Brom       Leicester     0     3   A
# ..   ..        ...    ...               ...             ...   ...   ...  ..
# 375  E0 2021-05-23  16:00         Liverpool  Crystal Palace     2     0   H
# 376  E0 2021-05-23  16:00          Man City         Everton     5     0   H
# 377  E0 2021-05-23  16:00  Sheffield United         Burnley     1     0   H
# 378  E0 2021-05-23  16:00          West Ham     Southampton     3     0   H
# 379  E0 2021-05-23  16:00            Wolves      Man United     1     2   A
#
# ...

# %% [markdown]
# ### Download the data for the French Ligue 2

# %%
pb.footballdata.fetch_data("France", 2020, 1)
# Out:
#     Div       Date   Time  HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    F2 2020-08-22  14:00  Toulouse     Dunkerque     0     1   A   0.0   0.0
# 1    F2 2020-08-22  18:00   Ajaccio   Chateauroux     0     1   A   0.0   0.0
# 2    F2 2020-08-22  18:00    Amiens         Nancy     1     0   H   0.0   0.0
# 3    F2 2020-08-22  18:00   Auxerre       Sochaux     0     2   A   0.0   1.0
# 4    F2 2020-08-22  18:00   Chambly      Paris FC     0     3   A   0.0   1.0
# ..   ..        ...    ...       ...           ...   ...   ...  ..   ...   ...
# 375  F2 2021-05-15  19:00     Nancy        Amiens     2     2   D   0.0   1.0
# 376  F2 2021-05-15  19:00     Niort      Guingamp     0     2   A   0.0   1.0
# 377  F2 2021-05-15  19:00  Paris FC       Chambly     3     0   H   0.0   0.0
# 378  F2 2021-05-15  19:00    Pau FC  Valenciennes     4     3   H   3.0   0.0
# 379  F2 2021-05-15  19:00   Sochaux       Auxerre     2     3   A   1.0   0.0
#
# ...

# %% [markdown]
# ### Download the Fourth tier of Scottish football

# %%
pb.footballdata.fetch_data("Scotland", 2020, 3)
# Out:
#      Div       Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SC3 2020-10-17  15:00   Albion Rvs   Stenhousemuir     1     3   A     0
# 1    SC3 2020-10-17  15:00      Brechin  Edinburgh City     1     5   A     0
# 2    SC3 2020-10-17  15:00  Cowdenbeath  Annan Athletic     0     3   A     0
# 3    SC3 2020-10-17  15:00     Stirling     Queens Park     0     0   D     0
# 4    SC3 2020-10-17  15:00    Stranraer           Elgin     1     4   A     0
# ..   ...        ...    ...          ...             ...   ...   ...  ..   ...
# 105  SC3 2021-05-01  15:00     Stirling       Stranraer     2     2   D     1
# 106  SC3 2021-05-04  19:00      Brechin   Stenhousemuir     0     1   A     0
# 107  SC3 2021-05-04  19:00  Cowdenbeath      Albion Rvs     2     0   H     1
# 108  SC3 2021-05-04  19:00        Elgin     Queens Park     3     2   H     0
# 109  SC3 2021-05-04  19:00    Stranraer  Edinburgh City     2     1   H     2
#
# ...
