# %%
import sys

sys.path.append("../../")

import pandas as pd

import penaltyblog as pb

# %% [markdown]
# ### Get the current active gameweek number

# %%
current_gameweek = pb.fpl.get_current_gameweek()
current_gameweek
# Out:
# 1

# %% [markdown]
# ### Get the weekly events
#
# This contains information on who the most captainied player was for each week week, what chips were played, what the highest score was etc

# %%
info = pb.fpl.get_gameweek_info()
info.query("average_entry_score > 0")
# Out:
#    id        name             deadline_time  average_entry_score  finished  \
# 0   1  Gameweek 1 2022-08-05 17:30:00+00:00                   23     False
#
#    data_checked  highest_scoring_entry  deadline_time_epoch  \
# 0         False              2749621.0           1659720600
#
#    deadline_time_game_offset  highest_score  ...  cup_leagues_created  \
# 0                          0           71.0  ...                False
#
#    h2h_ko_matches_created                                         chip_plays  \
# 0                   False  [{'chip_name': 'bboost', 'num_played': 170273}...
#
#    most_selected  most_transferred_in top_element           top_element_info  \
# 0           28.0                  1.0       313.0  {'id': 313, 'points': 12}
#
#    transfers_made  most_captained most_vice_captained
# 0               0           283.0               318.0
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Get Player Name to ID mappings

# %%
mappings = pb.fpl.get_player_id_mappings()
mappings.head()
# Out:
#   first_name   second_name web_name  id
# 0     Cédric  Alves Soares   Cédric   1
# 1     Granit         Xhaka    Xhaka   3
# 2    Mohamed        Elneny   Elneny   4
# 3        Rob       Holding  Holding   5
# 4     Thomas        Partey   Partey   6

# %% [markdown]
# ### Get the player data
#
# This contains information on each player, e.g. total score, total minutes played, form, current price etc

# %%
players = pb.fpl.get_player_data()
players.head()
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                           NaN                           NaN   58822
# 1                           NaN                           NaN  156074
# 2                         100.0                          75.0  192895
# 3                           NaN                           NaN  198869
# 4                          75.0                          75.0  223723
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                  0
# 1                  0                       0                  0
# 2                  0                       0                  0
# 3                  0                       0                  0
# 4                  0                       0                  0
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       0                0             2     2.3  ...
# 1                       0                0             2     2.3  ...
# 2                       0                0             2     2.8  ...
# 3                       0                0             2     2.3  ...
# 4                       0                0             2     1.8  ...
#
#   corners_and_indirect_freekicks_text  direct_freekicks_order  \
# 0                                                         3.0
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
#
#   direct_freekicks_text  penalties_order  penalties_text  position  \
# 0                                    NaN                  Defender
# 1                                    NaN                  Defender
# 2                                    NaN                  Defender
# 3                                    NaN                  Defender
# 4                                    NaN                  Defender
#
#   position_short team_id  team_name team_name_short
# 0            DEF       1    Arsenal             ARS
# 1            DEF       1    Arsenal             ARS
# 2            DEF       1    Arsenal             ARS
# 3            DEF       1    Arsenal             ARS
# 4            DEF       1    Arsenal             ARS
#
# [5 rows x 71 columns]

# %% [markdown]
# #### Let's extract the data for Oleksandr Zinchenko from the data frame

# %%
zincs = mappings.query("web_name == 'Zinchenko'")
zincs_id = zincs["id"].iloc[0]
players.query("id == @zincs_id")
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 9                           NaN                           NaN  206325
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 9                  0                       0                  0
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 9                       0                1             2     2.8  ...
#
#   corners_and_indirect_freekicks_text  direct_freekicks_order  \
# 9                                                         NaN
#
#   direct_freekicks_text  penalties_order  penalties_text  position  \
# 9                                    NaN                  Defender
#
#   position_short team_id  team_name team_name_short
# 9            DEF       1    Arsenal             ARS
#
# [1 rows x 71 columns]

# %% [markdown]
# #### Let's extract the data about goalkeepers

# %%
players.query("position_short == 'GKP'")[
    ["id", "first_name", "second_name", "position", "total_points", "minutes"]
].sort_values("total_points", ascending=False).head()
# Out:
#       id first_name     second_name    position  total_points  minutes
# 26    15      Aaron        Ramsdale  Goalkeeper             6       90
# 448  398       Dean       Henderson  Goalkeeper             2       41
# 193  152    Vicente          Guaita  Goalkeeper             1       90
# 556  478       José  Malheiro de Sá  Goalkeeper             1       43
# 508  425       Hugo          Lloris  Goalkeeper             1       44

# %% [markdown]
# ### Get Zinchenko's history by week for current season

# %%
history = pb.fpl.get_player_history(zincs_id)
history
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0      313        1              7            12     False
#
#                kickoff_time  team_h_score  team_a_score  round  minutes  ...  \
# 0 2022-08-05 19:00:00+00:00             0             2      1       82  ...
#
#    bps  influence  creativity  threat  ict_index  value  transfers_balance  \
# 0   38       40.0        23.3    21.0        8.4    5.0                  0
#
#    selected  transfers_in  transfers_out
# 0   1170032             0              0
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Fetch the current top 50 ranked FPL teams

# %%
pb.fpl.get_rankings(1)
# Out:
#           id  event_total           player_name  rank  last_rank  rank_sort  \
# 0   55733942           71         Simon Sjölund     1          0          1
# 1   56948368           71           Thom Pichon     1          0          2
# 2   15879108           71         Jordan Holmes     1          0          3
# 3    4964881           70    greg tai LE402 SJI     4          0          4
# 4   50997447           70        Jarle Kvamsdal     4          0          5
# 5   35746412           70   Remi ruben Sandberg     4          0          6
# 6   51389648           70         Daniel Daniel     4          0          7
# 7   52591723           70     nemanja vucenovic     4          0          8
# 8   34392632           69            Shea Joffe     9          0          9
# 9   11321657           69   Imnoursh alshumrani     9          0         10
# 10  24233264           69            Suzie Iles     9          0         11
# 11  29311131           69          yasser magdy     9          0         12
# 12  34550512           69               Ams Mas     9          0         13
# 13  35407708           69              Roy Gavi     9          0         14
# 14  38832874           69       Henrik Elfstedt     9          0         15
# 15  43805070           69             Rúnar Þor     9          0         16
# 16  46909008           69       adeyemi aderemi     9          0         17
# 17  21577637           68      Lufuno Mushabalo    18          0         18
# 18  29247892           68           Obinna Tony    18          0         19
# 19  30982823           68          Erik Klompen    18          0         20
# 20  51524562           68  Jakub Andruszkiewicz    18          0         21
# 21   8499514           67        George Dazeley    22          0         22
# 22  32780655           67             Rocky Bai    22          0         23
# 23  36037266           67     Tin Tadić Smojver    22          0         24
# 24  16347873           67           EDEN MUGUME    22          0         25
# 25  22668289           67   Chukwunomnso Iwegbu    22          0         26
# 26  29721705           67           naser seryo    22          0         27
# 27  32978560           67         Igor Pavlovic    22          0         28
# 28  32381410           67      Suiiiiiii Ewyyyy    22          0         29
# 29  10463436           66          Cemo Jimmy ❕    30          0         30
# 30  17349136           66           László Tóth    30          0         31
# 31  41237175           66       Hammed Sofoluwe    30          0         32
# 32   9044019           66       Mahmoud Mahmoud    30          0         33
# 33  18221271           66                   N G    30          0         34
# 34  39437669           66       sofiane barbant    30          0         35
# 35  47006210           66       Trevor Mccollin    30          0         36
# 36  48445031           66     Mohamed Abdelazim    30          0         37
# 39         90     65  4324403           Scuba Squad
# 40         91     65  4761146             Alley God
# 41         92     65  5815017       Monbeastdaddyfc
# 42         93     64  4747354           greg tai 11
# 43         94     64  7035101         Caseynator FC
# 44         95     64   864615    Fofanas in Pyjamas
# 45         96     64  5330138    narenho's hotshots
# 46         97     64  5114441                  K9FC
# 47         98     64   117569             Ari� Ana�
# 48         99     64   747063                mhmddd
# 49        100     64  3346423   English Soccer Team

# %% [markdown]
# ### Fetch a team's player picks by gameweek

# %%
pb.fpl.get_entry_picks_by_gameweek(1000, 1)
# Out:
#    team_id active_chip  event  points  total_points    rank  rank_sort  \
# 0     1000        None      1      39            39  554164     554239
#
#    overall_rank  value  bank  ...  player_pick_7  player_pick_8  \
# 0        554164  100.0   0.5  ...             19            486
#
#    player_pick_9 player_pick_10 player_pick_11 player_pick_12 player_pick_13  \
# 0            318             28            254             54            295
#
#    player_pick_14  captain_id  is_vice_captain
# 0             346         283              318
#
# [1 rows x 34 columns]

# %% [markdown]
# ### Get entry's transfer history for this season

# %%
pb.fpl.get_entry_transfers(100)

# %% [markdown]
# ### Get optimal fantasy football squad for a budget of £100m

# %%
optimiser_results, team = pb.fpl.optimise_team(budget=100)

optimiser_results
# Out:
# {'status': 'Optimal', 'total_points': 97.0, 'total_price': 90.0}

# %%
team
# Out:
#      id               full_name team position  price  total_points
# 0    15          Aaron Ramsdale  ARS      GKP    5.0             6
# 1   398          Dean Henderson  NFO      GKP    4.5             2
# 2   313     Oleksandr Zinchenko  ARS      DEF    5.0            12
# 3    26          William Saliba  ARS      DEF    4.5             8
# 4   430               Eric Dier  TOT      DEF    5.0             7
# 5   436          Ryan Sessegnon  TOT      DEF    4.5             6
# 6   215              Kenny Tete  FUL      DEF    4.5             3
# 7   283           Mohamed Salah  LIV      MID   13.0            10
# 8    64   Jefferson Lerma Solís  BOU      MID    5.0             6
# 9   225          Rodrigo Moreno  LEE      MID    6.0             6
# 10  407       James Ward-Prowse  SOU      MID    6.5             6
# 11  483  Daniel Castelo Podence  WOL      MID    5.5             6
# 12  210     Aleksandar Mitrović  FUL      FWD    6.5            10
# 13  297    Darwin Núñez Ribeiro  LIV      FWD    9.0             8
# 14  408          Adam Armstrong  SOU      FWD    5.5             1

# %% [markdown]
# ### Get optimal fantasy football first eleven if playing 3-5-2 if spending £85m

# %%
optimiser_results, team = pb.fpl.optimise_team(formation="1-3-5-2", budget=85)

optimiser_results
# Out:
# {'status': 'Optimal', 'total_points': 85.0, 'total_price': 71.0}

# %%
team
# Out:
#      id               full_name team position  price  total_points
# 0    15          Aaron Ramsdale  ARS      GKP    5.0             6
# 1   313     Oleksandr Zinchenko  ARS      DEF    5.0            12
# 2    26          William Saliba  ARS      DEF    4.5             8
# 3   430               Eric Dier  TOT      DEF    5.0             7
# 4   283           Mohamed Salah  LIV      MID   13.0            10
# 5    64   Jefferson Lerma Solís  BOU      MID    5.0             6
# 6   225          Rodrigo Moreno  LEE      MID    6.0             6
# 7   407       James Ward-Prowse  SOU      MID    6.5             6
# 8   483  Daniel Castelo Podence  WOL      MID    5.5             6
# 9   210     Aleksandar Mitrović  FUL      FWD    6.5            10
# 10  297    Darwin Núñez Ribeiro  LIV      FWD    9.0             8
