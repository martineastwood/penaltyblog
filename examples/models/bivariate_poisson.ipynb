# %% [markdown]
# # Bayesian Bivariate Model

# %%
import sys

sys.path.append("../../")

import penaltyblog as pb

# %% [markdown]
# ## Get data from football-data.co.uk

# %%
fb = pb.scrapers.FootballData("ENG Premier League", "2019-2020")
df = fb.get_fixtures()

df.head()
# Out:
#                                                   date            datetime  \
# id
# 1565308800---liverpool---norwich            2019-08-09 2019-08-09 20:00:00
# 1565395200---bournemouth---sheffield_united 2019-08-10 2019-08-10 15:00:00
# 1565395200---burnley---southampton          2019-08-10 2019-08-10 15:00:00
# 1565395200---crystal_palace---everton       2019-08-10 2019-08-10 15:00:00
# 1565395200---tottenham---aston_villa        2019-08-10 2019-08-10 17:30:00
#
#                                                 season         competition  \
# id
# 1565308800---liverpool---norwich             2019-2020  ENG Premier League
# 1565395200---bournemouth---sheffield_united  2019-2020  ENG Premier League
# 1565395200---burnley---southampton           2019-2020  ENG Premier League
# 1565395200---crystal_palace---everton        2019-2020  ENG Premier League
# 1565395200---tottenham---aston_villa         2019-2020  ENG Premier League
#
#                                             div   time       team_home  \
# id
# 1565308800---liverpool---norwich             E0  20:00       Liverpool
# 1565395200---bournemouth---sheffield_united  E0  15:00     Bournemouth
# 1565395200---burnley---southampton           E0  15:00         Burnley
# 1565395200---crystal_palace---everton        E0  15:00  Crystal Palace
# 1565395200---tottenham---aston_villa         E0  17:30       Tottenham
#
#                                                     team_away  fthg  ftag  \
# id
# 1565308800---liverpool---norwich                      Norwich     4     1
# 1565395200---bournemouth---sheffield_united  Sheffield United     1     1
# 1565395200---burnley---southampton                Southampton     3     0
# 1565395200---crystal_palace---everton                 Everton     0     0
# 1565395200---tottenham---aston_villa              Aston Villa     3     1
#
#                                              ... b365_cahh  b365_caha  pcahh  \
# id                                           ...
# 1565308800---liverpool---norwich             ...      1.91       1.99   1.94
# 1565395200---bournemouth---sheffield_united  ...      1.95       1.95   1.98
# 1565395200---burnley---southampton           ...      1.87       2.03   1.89
# 1565395200---crystal_palace---everton        ...      1.82       2.08   1.97
# 1565395200---tottenham---aston_villa         ...      2.10       1.70   2.18
#
#                                             pcaha max_cahh  max_caha  \
# id
# 1565308800---liverpool---norwich             1.98     1.99      2.07
# 1565395200---bournemouth---sheffield_united  1.95     2.00      1.96
# 1565395200---burnley---southampton           2.03     1.90      2.07
# 1565395200---crystal_palace---everton        1.96     2.03      2.08
# 1565395200---tottenham---aston_villa         1.77     2.21      1.87
#
#                                              avg_cahh  avg_caha  goals_home  \
# id
# 1565308800---liverpool---norwich                 1.90      1.99           4
# 1565395200---bournemouth---sheffield_united      1.96      1.92           1
# 1565395200---burnley---southampton               1.86      2.02           3
# 1565395200---crystal_palace---everton            1.96      1.93           0
# 1565395200---tottenham---aston_villa             2.08      1.80           3
#
#                                              goals_away
# id
# 1565308800---liverpool---norwich                      1
# 1565395200---bournemouth---sheffield_united           1
# 1565395200---burnley---southampton                    0
# 1565395200---crystal_palace---everton                 0
# 1565395200---tottenham---aston_villa                  1
#
# [5 rows x 111 columns]

# %% [markdown]
# ## Train the Model

# %%
clf = pb.models.BivariatePoissonGoalModel(
    df["goals_home"], df["goals_away"], df["team_home"], df["team_away"]
)
clf.fit()

# %% [markdown]
# ## The model's parameters

# %%
clf
# Out:
# Module: Penaltyblog
#
# Model: Bivariate Poisson
#
# Number of parameters: 42
# Log Likelihood: -1059.876
# AIC: 2203.752
#
# Team                 Attack               Defence
# ------------------------------------------------------------
# Arsenal              0.12                 0.027
# Aston Villa          -0.178               0.362
# Bournemouth          -0.212               0.326
# Brighton             -0.246               0.136
# Burnley              -0.131               0.075
# Chelsea              0.343                0.163
# Crystal Palace       -0.478               0.056
# Everton              -0.128               0.171
# Leicester            0.312                -0.105
# Liverpool            0.537                -0.334
# Man City             0.732                -0.235
# Man United           0.281                -0.26
# Newcastle            -0.266               0.211
# Norwich              -0.653               0.461
# Sheffield United     -0.257               -0.199
# Southampton          0.046                0.263
# Tottenham            0.208                0.01
# Watford              -0.308               0.315
# West Ham             0.001                0.289
# Wolves               0.012                -0.173
# ------------------------------------------------------------
# Home Advantage: 0.237
# Correlation: -3.0

# %%
clf.get_params()
# Out:
# {'attack_Arsenal': np.float64(0.12015884001818536),
#  'attack_Aston Villa': np.float64(-0.178289609870808),
#  'attack_Bournemouth': np.float64(-0.21186839967414306),
#  'attack_Brighton': np.float64(-0.24598380613425747),
#  'attack_Burnley': np.float64(-0.13115620343058873),
#  'attack_Chelsea': np.float64(0.34289271659983556),
#  'attack_Crystal Palace': np.float64(-0.4784803052934038),
#  'attack_Everton': np.float64(-0.12793440484566818),
#  'attack_Leicester': np.float64(0.3119262253341013),
#  'attack_Liverpool': np.float64(0.5365996919509738),
#  'attack_Man City': np.float64(0.7316415304304199),
#  'attack_Man United': np.float64(0.28051067946136676),
#  'attack_Newcastle': np.float64(-0.2663381195846516),
#  'attack_Norwich': np.float64(-0.6528101601028435),
#  'attack_Sheffield United': np.float64(-0.25723461735263614),
#  'attack_Southampton': np.float64(0.046076014510768766),
#  'attack_Tottenham': np.float64(0.20805829676679571),
#  'attack_Watford': np.float64(-0.3079658423042679),
#  'attack_West Ham': np.float64(0.0006019472047279404),
#  'attack_Wolves': np.float64(0.011707431460455687),
#  'defense_Arsenal': np.float64(0.026599276258560844),
#  'defense_Aston Villa': np.float64(0.361682898230907),
#  'defense_Bournemouth': np.float64(0.32596254865808016),
#  'defense_Brighton': np.float64(0.13594468331339157),
#  'defense_Burnley': np.float64(0.07484709254485093),
#  'defense_Chelsea': np.float64(0.16348122088985756),
#  'defense_Crystal Palace': np.float64(0.056354672747875895),
#  'defense_Everton': np.float64(0.17076957900708167),
#  'defense_Leicester': np.float64(-0.10536445396338834),
#  'defense_Liverpool': np.float64(-0.3335976364223472),
#  'defense_Man City': np.float64(-0.23515681745800263),
#  'defense_Man United': np.float64(-0.2603359839766639),
#  'defense_Newcastle': np.float64(0.21058208895618027),
#  'defense_Norwich': np.float64(0.4610785428998152),
#  'defense_Sheffield United': np.float64(-0.19862493152238944),
#  'defense_Southampton': np.float64(0.26255388485581277),
#  'defense_Tottenham': np.float64(0.010220753561804326),
#  'defense_Watford': np.float64(0.31485167989003404),
#  'defense_West Ham': np.float64(0.2891414234087545),
#  'defense_Wolves': np.float64(-0.17341560576877246),
#  'home_advantage': np.float64(0.2369067644177771),
#  'correlation_log': np.float64(-3.0),
#  'lambda3': np.float64(0.049787068367863944)}

# %% [markdown]
# ## Predict Match Outcomes

# %%
probs = clf.predict("Liverpool", "Wolves")
probs
# Out:
# Module: Penaltyblog
#
# Class: FootballProbabilityGrid
#
# Home Goal Expectation: 1.822284348496715
# Away Goal Expectation: 0.7247777629635875
#
# Home Win: 0.6357199700706624
# Draw: 0.22134063673373003
# Away Win: 0.14291246559558518

# %% [markdown]
# ### 1x2 Probabilities

# %%
probs.home_draw_away
# Out:
# [np.float64(0.6357199700706624),
#  np.float64(0.22134063673373003),
#  np.float64(0.14291246559558518)]

# %%
probs.home_win
# Out:
# np.float64(0.6357199700706624)

# %%
probs.draw
# Out:
# np.float64(0.22134063673373003)

# %%
probs.away_win
# Out:
# np.float64(0.14291246559558518)

# %% [markdown]
# ### Probablity of Total Goals >1.5

# %%
probs.total_goals("over", 1.5)
# Out:
# np.float64(0.7356886751103631)

# %% [markdown]
# ### Probability of Asian Handicap 1.5

# %%
probs.asian_handicap("home", 1.5)
# Out:
# np.float64(0.37558975220411517)

# %% [markdown]
# ## Probability of both teams scoring

# %%
probs.both_teams_to_score
# Out:
# np.float64(0.45978190339795716)

# %% [markdown]
# ## Train the model with more recent data weighted to be more important

# %%
weights = pb.models.dixon_coles_weights(df["date"], 0.001)

clf = pb.models.BayesianBivariateGoalModel(
    df["goals_home"], df["goals_away"], df["team_home"], df["team_away"], weights
)
clf.fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 weights = pb.models.dixon_coles_weights(df["date"], 0.001)
# ----> 3 clf = pb.models.BayesianBivariateGoalModel(
#       4     df["goals_home"], df["goals_away"], df["team_home"], df["team_away"], weights
#       5 )
#       6 clf.fit()
#
# AttributeError: module 'penaltyblog.models' has no attribute 'BayesianBivariateGoalModel'

# %%
clf
