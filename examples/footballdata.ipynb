# %% [markdown]
# # football-data.co.uk

# %%
import sys
sys.path.append("../")

from penaltyblog.scrapers import FootballData

# %% [markdown]
# ### List the available countries to download data for

# %%
FootballData.list_competitions()
# Out:
# ['DEU Bundesliga 1',
#  'DEU Bundesliga 2',
#  'ENG Premier League',
#  'ENG Championship',
#  'ENG League 1',
#  'ENG League 2',
#  'ENG Conference',
#  'FRA Ligue 1',
#  'FRA Ligue 2',
#  'GRC Super League',
#  'ITA Serie A',
#  'ITA Serie B',
#  'NLD Eredivisie',
#  'PRT Liga 1',
#  'SCO Premier League',
#  'SCO Division 1',
#  'SCO Division 2',
#  'SCO Division 3',
#  'TUR Super Lig']

# %% [markdown]
# ### Download the data for the English Premier League

# %%
fb = FootballData("ENG Premier League", "2019-2020")
df = fb.get_fixtures()

df.head()
# Out:
#                                                                              div  \
# competition        season    id
# ENG Premier League 2019-2020 1565308800---liverpool---norwich_city            E0
#                              1565395200---afc_bournemouth---sheffield_united  E0
#                              1565395200---burnley---southampton               E0
#                              1565395200---crystal_palace---everton            E0
#                              1565395200---tottenham_hotspur---aston_villa     E0
#
#                                                                                       team_home  \
# competition        season    id
# ENG Premier League 2019-2020 1565308800---liverpool---norwich_city                    Liverpool
#                              1565395200---afc_bournemouth---sheffield_united    AFC Bournemouth
#                              1565395200---burnley---southampton                         Burnley
# ...

# %% [markdown]
# ### Download the data for the French Ligue 2

# %%
fb = FootballData("FRA Ligue 2", "2021-2022")
df = fb.get_fixtures()

df.head()
# Out:
#                                                               div  team_home  \
# competition season    id
# FRA Ligue 2 2021-2022 1627084800---amiens---auxerre            F2     Amiens
#                       1627084800---bastia---nimes              F2     Bastia
#                       1627084800---caen---rodez                F2       Caen
#                       1627084800---dunkerque---quevilly_rouen  F2  Dunkerque
#                       1627084800---grenoble---paris_fc         F2   Grenoble
#
#                                                                     team_away  \
# competition season    id
# FRA Ligue 2 2021-2022 1627084800---amiens---auxerre                   Auxerre
#                       1627084800---bastia---nimes                       Nimes
#                       1627084800---caen---rodez                         Rodez
#                       1627084800---dunkerque---quevilly_rouen  Quevilly Rouen
# ...
