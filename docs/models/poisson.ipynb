# %% [markdown]
# # Poisson

# %%
import sys

sys.path.append("../../")

import penaltyblog as pb

# %% [markdown]
# ## Get data from football-data.co.uk

# %%
fb = pb.scrapers.FootballData("ENG Premier League", "2019-2020")
df = fb.get_fixtures()

df.head()
# Out:
#                                                   date            datetime  \
# id
# 1565308800---liverpool---norwich            2019-08-09 2019-08-09 20:00:00
# 1565395200---bournemouth---sheffield_united 2019-08-10 2019-08-10 15:00:00
# 1565395200---burnley---southampton          2019-08-10 2019-08-10 15:00:00
# 1565395200---crystal_palace---everton       2019-08-10 2019-08-10 15:00:00
# 1565395200---tottenham---aston_villa        2019-08-10 2019-08-10 17:30:00
#
#                                                 season         competition  \
# id
# 1565308800---liverpool---norwich             2019-2020  ENG Premier League
# 1565395200---bournemouth---sheffield_united  2019-2020  ENG Premier League
# 1565395200---burnley---southampton           2019-2020  ENG Premier League
# 1565395200---crystal_palace---everton        2019-2020  ENG Premier League
# 1565395200---tottenham---aston_villa         2019-2020  ENG Premier League
#
#                                             div   time       team_home  \
# id
# 1565308800---liverpool---norwich             E0  20:00       Liverpool
# 1565395200---bournemouth---sheffield_united  E0  15:00     Bournemouth
# 1565395200---burnley---southampton           E0  15:00         Burnley
# 1565395200---crystal_palace---everton        E0  15:00  Crystal Palace
# 1565395200---tottenham---aston_villa         E0  17:30       Tottenham
#
#                                                     team_away  fthg  ftag  \
# id
# 1565308800---liverpool---norwich                      Norwich     4     1
# 1565395200---bournemouth---sheffield_united  Sheffield United     1     1
# 1565395200---burnley---southampton                Southampton     3     0
# 1565395200---crystal_palace---everton                 Everton     0     0
# 1565395200---tottenham---aston_villa              Aston Villa     3     1
#
#                                              ... b365_cahh  b365_caha  pcahh  \
# id                                           ...
# 1565308800---liverpool---norwich             ...      1.91       1.99   1.94
# 1565395200---bournemouth---sheffield_united  ...      1.95       1.95   1.98
# 1565395200---burnley---southampton           ...      1.87       2.03   1.89
# 1565395200---crystal_palace---everton        ...      1.82       2.08   1.97
# 1565395200---tottenham---aston_villa         ...      2.10       1.70   2.18
#
#                                             pcaha max_cahh  max_caha  \
# id
# 1565308800---liverpool---norwich             1.98     1.99      2.07
# 1565395200---bournemouth---sheffield_united  1.95     2.00      1.96
# 1565395200---burnley---southampton           2.03     1.90      2.07
# 1565395200---crystal_palace---everton        1.96     2.03      2.08
# 1565395200---tottenham---aston_villa         1.77     2.21      1.87
#
#                                              avg_cahh  avg_caha  goals_home  \
# id
# 1565308800---liverpool---norwich                 1.90      1.99           4
# 1565395200---bournemouth---sheffield_united      1.96      1.92           1
# 1565395200---burnley---southampton               1.86      2.02           3
# 1565395200---crystal_palace---everton            1.96      1.93           0
# 1565395200---tottenham---aston_villa             2.08      1.80           3
#
#                                              goals_away
# id
# 1565308800---liverpool---norwich                      1
# 1565395200---bournemouth---sheffield_united           1
# 1565395200---burnley---southampton                    0
# 1565395200---crystal_palace---everton                 0
# 1565395200---tottenham---aston_villa                  1
#
# [5 rows x 111 columns]

# %% [markdown]
# ## Train a basic poisson model

# %%
clf = pb.models.PoissonGoalsModel(
    df["goals_home"], df["goals_away"], df["team_home"], df["team_away"]
)
clf.fit()

# %% [markdown]
# ## The model's parameters

# %%
clf
# Out:
# Module: Penaltyblog
#
# Model: Poisson
#
# Number of parameters: 41
# Log Likelihood: -1057.712
# AIC: 2197.424
#
# Team                 Attack               Defence
# ------------------------------------------------------------
# Arsenal              1.133                -0.937
# Aston Villa          0.84                 -0.618
# Bournemouth          0.813                -0.65
# Brighton             0.777                -0.837
# Burnley              0.87                 -0.91
# Chelsea              1.349                -0.806
# Crystal Palace       0.543                -0.922
# Everton              0.899                -0.795
# Leicester            1.306                -1.084
# Liverpool            1.536                -1.283
# Man City             1.721                -1.206
# Man United           1.286                -1.216
# Newcastle            0.755                -0.766
# Norwich              0.391                -0.521
# Sheffield United     0.761                -1.163
# Southampton          1.052                -0.719
# Tottenham            1.218                -0.953
# Watford              0.706                -0.669
# West Ham             1.014                -0.688
# Wolves               1.031                -1.125
# ------------------------------------------------------------
# Home Advantage: 0.229

# %%
clf.get_params()
# Out:
# {'attack_Arsenal': np.float64(1.1331227001062658),
#  'attack_Aston Villa': np.float64(0.8398886920035256),
#  'attack_Bournemouth': np.float64(0.8130899119060918),
#  'attack_Brighton': np.float64(0.7765242862829769),
#  'attack_Burnley': np.float64(0.8703021546219181),
#  'attack_Chelsea': np.float64(1.3487332417539546),
#  'attack_Crystal Palace': np.float64(0.5425421901524462),
#  'attack_Everton': np.float64(0.8994388718838547),
#  'attack_Leicester': np.float64(1.3056838961937691),
#  'attack_Liverpool': np.float64(1.5361422180452606),
#  'attack_Man City': np.float64(1.7212740933293338),
#  'attack_Man United': np.float64(1.2855298361869565),
#  'attack_Newcastle': np.float64(0.7545390499059659),
#  'attack_Norwich': np.float64(0.39112515551979643),
#  'attack_Sheffield United': np.float64(0.7614760264604242),
#  'attack_Southampton': np.float64(1.0516119013807126),
#  'attack_Tottenham': np.float64(1.217788887350299),
#  'attack_Watford': np.float64(0.7064644847198257),
#  'attack_West Ham': np.float64(1.0135090229624062),
#  'attack_Wolves': np.float64(1.0312133792289104),
#  'defence_Arsenal': np.float64(-0.9373595954301052),
#  'defence_Aston Villa': np.float64(-0.6183892118251706),
#  'defence_Bournemouth': np.float64(-0.6497774115613173),
#  'defence_Brighton': np.float64(-0.8366648775701425),
#  'defence_Burnley': np.float64(-0.9096446247376822),
#  'defence_Chelsea': np.float64(-0.805679080722898),
#  'defence_Crystal Palace': np.float64(-0.9217226534473918),
#  'defence_Everton': np.float64(-0.795083727031885),
#  'defence_Leicester': np.float64(-1.0841121057363725),
#  'defence_Liverpool': np.float64(-1.28337158106114),
#  'defence_Man City': np.float64(-1.2063233494887704),
#  'defence_Man United': np.float64(-1.215631914120363),
#  'defence_Newcastle': np.float64(-0.7660204152449437),
#  'defence_Norwich': np.float64(-0.5206708607401189),
#  'defence_Sheffield United': np.float64(-1.162693732090905),
#  'defence_Southampton': np.float64(-0.7187480284686788),
#  'defence_Tottenham': np.float64(-0.9533486322158317),
#  'defence_Watford': np.float64(-0.669385869765317),
#  'defence_West Ham': np.float64(-0.6878746839697923),
#  'defence_Wolves': np.float64(-1.1252400440010037),
#  'home_advantage': np.float64(0.22925222041902432)}

# %% [markdown]
# ## Predict Match Outcomes

# %%
probs = clf.predict("Liverpool", "Wolves")
probs
# Out:
# Module: Penaltyblog
#
# Class: FootballProbabilityGrid
#
# Home Goal Expectation: 1.896773708057422
# Away Goal Expectation: 0.7771217862531506
#
# Home Win: 0.6385327031486729
# Draw: 0.21487327868334663
# Away Win: 0.14659401624342525

# %% [markdown]
# ### 1x2 Probabilities

# %%
probs.home_draw_away
# Out:
# [np.float64(0.6385327031486729),
#  np.float64(0.21487327868334663),
#  np.float64(0.14659401624342525)]

# %%
probs.home_win
# Out:
# np.float64(0.6385327031486729)

# %%
probs.draw
# Out:
# np.float64(0.21487327868334663)

# %%
probs.away_win
# Out:
# np.float64(0.14659401624342525)

# %% [markdown]
# ### Probablity of Total Goals >1.5

# %%
probs.total_goals("over", 1.5)
# Out:
# np.float64(0.7465637444557348)

# %% [markdown]
# ### Probability of Asian Handicap 1.5

# %%
probs.asian_handicap("home", 1.5)
# Out:
# np.float64(0.38442657025826804)

# %% [markdown]
# ## Probability of both teams scoring

# %%
probs.both_teams_to_score
# Out:
# np.float64(0.45920372451133795)
